# %% [markdown]
# # Search App

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
immo = pd.read_csv('immo.csv')

# %%
def menu():
    print("MAINMENU \"INFO BASE RENT GERMANY\".")
    print("Press [1] Info base rent germany.")
    print("Press [2] Postal code search.")
    print("Press [3] City search.")
    print("Press [4] Federal state search..")
    print("Press [5] deep City search.")
    print("Press [6] to exit the program.")
    print("")

command_1 = 0

while command_1 != 6:
    menu()
    try:
        command_1 = int(
            input("Please chose an option by pressing number [1] - [6] and confirm afterwards with [Enter].\n"))
        print("")
    except ValueError:
        print("invalid input")
        input("Press [Enter] to go back to menu.\n")
    if command_1 == 1:
        try:
            print("")
            print("AVERAGE BASE RENT IN FEDERAL STATE OF GERMANY:")
            print("")
            nrw = immo.loc[immo['regio1'] == 'Nordrhein_Westfalen']
            print(len(nrw), "records found in Nordrhein Westfalen:")
            print("The average base rent in Nordrhein Westfalen is: ", round(nrw['baseRent'].mean(),2), "Euro/month")
            print("The minimum base rent in Nordrhein Westfalen is: ", round(nrw['baseRent'].min(),2), "Euro/month")
            print("The maximum base rent in Nordrhein Westfalen is: ", round(nrw['baseRent'].max(),2), "Euro/month")
            print("")
            nrw = immo.loc[immo['regio1'] == 'Sachsen']
            print(len(nrw), "records found in Sachsen:")
            print("The average base rent in Sachsen is: ", round(nrw['baseRent'].mean(),2), "Euro/month")
            print("The minimum base rent in Sachsen is: ", round(nrw['baseRent'].min(),2), "Euro/month")
            print("The maximum base rent in Sachsen is: ", round(nrw['baseRent'].max(),2), "Euro/month")
            print("")
            nrw = immo.loc[immo['regio1'] == 'Bayern']
            print(len(nrw), "records found in Bayern:")
            print("The average base rent in Bayern is: ", round(nrw['baseRent'].mean(),2), "Euro/month")
            print("The minimum base rent in Bayern is: ", round(nrw['baseRent'].min(),2), "Euro/month")
            print("The maximum base rent in Bayern is: ", round(nrw['baseRent'].max(),2), "Euro/month")
            print("")
            nrw = immo.loc[immo['regio1'] == 'Sachsen_Anhalt']
            print(len(nrw), "records found in Sachsen Anhalt:")
            print("The average base rent in Sachsen Anhalt is: ", round(nrw['baseRent'].mean(),2), "Euro/month")
            print("The minimum base rent in Sachsen Anhalt is: ", round(nrw['baseRent'].min(),2), "Euro/month")
            print("The maximum base rent in Sachsen Anhalt is: ", round(nrw['baseRent'].max(),2), "Euro/month")
            print("")
            nrw = immo.loc[immo['regio1'] == 'Hessen']
            print(len(nrw), "records found in Hessen:")
            print("The average base rent in Hessen is: ", round(nrw['baseRent'].mean(),2), "Euro/month")
            print("The minimum base rent in Hessen is: ", round(nrw['baseRent'].min(),2), "Euro/month")
            print("The maximum base rent in Hessen is: ", round(nrw['baseRent'].max(),2), "Euro/month")
            print("")
            nrw = immo.loc[immo['regio1'] == 'Niedersachsen']
            print(len(nrw), "records found in Niedersachsen:")
            print("The average base rent in Niedersachsen is: ", round(nrw['baseRent'].mean(),2), "Euro/month")
            print("The minimum base rent in Niedersachsen is: ", round(nrw['baseRent'].min(),2), "Euro/month")
            print("The maximum base rent in Niedersachsen is: ", round(nrw['baseRent'].max(),2), "Euro/month")
            print("")
            nrw = immo.loc[immo['regio1'] == 'Baden_Württemberg']
            print(len(nrw), "records found in Baden_Württemberg:")
            print("The average base rent in Baden Württemberg is: ", round(nrw['baseRent'].mean(),2), "Euro/month")
            print("The minimum base rent in Baden Württemberg is: ", round(nrw['baseRent'].min(),2), "Euro/month")
            print("The maximum base rent in Baden Württemberg is: ", round(nrw['baseRent'].max(),2), "Euro/month")
            print("")
            nrw = immo.loc[immo['regio1'] == 'Berlin']
            print(len(nrw), "records found in Berlin:")
            print("The average base rent in Berlin is: ", round(nrw['baseRent'].mean(),2), "Euro/month")
            print("The minimum base rent in Berlin is: ", round(nrw['baseRent'].min(),2), "Euro/month")
            print("The maximum base rent in Berlin is: ", round(nrw['baseRent'].max(),2), "Euro/month")
            print("")
            nrw = immo.loc[immo['regio1'] == 'Thüringen']
            print(len(nrw), "records found in Thüringen:")
            print("The average base rent in Thüringen is: ", round(nrw['baseRent'].mean(),2), "Euro/month")
            print("The minimum base rent in Thüringen is: ", round(nrw['baseRent'].min(),2), "Euro/month")
            print("The maximum base rent in Thüringen is: ", round(nrw['baseRent'].max(),2), "Euro/month")
            print("")
            nrw = immo.loc[immo['regio1'] == 'Rheinland_Pfalz']
            print(len(nrw), "records found in Rheinland Pfalz:")
            print("The average base rent in Rheinland Pfalz is: ", round(nrw['baseRent'].mean(),2), "Euro/month")
            print("The minimum base rent in Rheinland Pfalz is: ", round(nrw['baseRent'].min(),2), "Euro/month")
            print("The maximum base rent in Rheinland Pfalz is: ", round(nrw['baseRent'].max(),2), "Euro/month")
            print("")
            nrw = immo.loc[immo['regio1'] == 'Brandenburg']
            print(len(nrw), "records found in Brandenburg:")
            print("The average base rent in Brandenburg is: ", round(nrw['baseRent'].mean(),2), "Euro/month")
            print("The minimum base rent in Brandenburg is: ", round(nrw['baseRent'].min(),2), "Euro/month")
            print("The maximum base rent in Brandenburg is: ", round(nrw['baseRent'].max(),2), "Euro/month")
            print("")
            nrw = immo.loc[immo['regio1'] == 'Schleswig_Holstein']
            print(len(nrw), "records found in Schleswig Holstein:")
            print("The average base rent in Schleswig Holstein is: ", round(nrw['baseRent'].mean(),2), "Euro/month")
            print("The minimum base rent in Schleswig Holstein is: ", round(nrw['baseRent'].min(),2), "Euro/month")
            print("The maximum base rent in Schleswig Holstein is: ", round(nrw['baseRent'].max(),2), "Euro/month")
            print("")
            nrw = immo.loc[immo['regio1'] == 'Mecklenburg_Vorpommern']
            print(len(nrw), "records found in Mecklenburg Vorpommern:")
            print("The average base rent in Mecklenburg Vorpommern is: ", round(nrw['baseRent'].mean(),2), "Euro/month")
            print("The minimum base rent in Mecklenburg Vorpommern is: ", round(nrw['baseRent'].min(),2), "Euro/month")
            print("The maximum base rent in Mecklenburg Vorpommern is: ", round(nrw['baseRent'].max(),2), "Euro/month")
            print("")
            nrw = immo.loc[immo['regio1'] == 'Hamburg']
            print(len(nrw), "records found in Hamburg:")
            print("The average base rent in Hamburg is: ", round(nrw['baseRent'].mean(),2), "Euro/month")
            print("The minimum base rent in Hamburg is: ", round(nrw['baseRent'].min(),2), "Euro/month")
            print("The maximum base rent in Hamburg is: ", round(nrw['baseRent'].max(),2), "Euro/month")
            print("")
            nrw = immo.loc[immo['regio1'] == 'Bremen']
            print(len(nrw), "records found in Bremen:")
            print("The average base rent in Bremen is: ", round(nrw['baseRent'].mean(),2), "Euro/month")
            print("The minimum base rent in Bremen is: ", round(nrw['baseRent'].min(),2), "Euro/month")
            print("The maximum base rent in Bremen is: ", round(nrw['baseRent'].max(),2), "Euro/month")
            print("")
            nrw = immo.loc[immo['regio1'] == 'Saarland']
            print(len(nrw), "records found in Saarland:")
            print("The average base rent in Saarland is: ", round(nrw['baseRent'].mean(),2), "Euro/month")
            print("The minimum base rent in Saarland is: ", round(nrw['baseRent'].min(),2), "Euro/month")
            print("The maximum base rent in Saarland is: ", round(nrw['baseRent'].max(),2), "Euro/month")
            print("")
            plt.figure(figsize = (20,10))
            ax = sns.barplot(x = 'regio1', y = 'baseRent', data = immo)
            ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
            title = print("Base Rent Vs Region")
            plt.title(title, fontsize = 20)
            plt.xlabel('Region', fontsize = 16)
            plt.ylabel('base Rent', fontsize = 16)
            plt.show()
            input("Press [Enter] to go back to menu.\n")
        except ValueError:
            print("invalid input")
            input("Press [Enter] to go back to menu.\n")
    elif command_1 == 2:
        try:
            plz = int(input("please type a postal code: \n"))
            plz_1 = immo.loc[immo['geo_plz'] == plz]
        except ValueError:
            print("invalid input")
            input("Press [Enter] to go back to menu.\n")
        if plz > 1:
            print("")
            print('Number of records found: ', len(plz_1))
            print("The average base rent in postal code",str(plz),"is", round(plz_1['baseRent'].mean(),2), "Euro/month")
            print("The minimum base rent in postal code",str(plz),"is", round(plz_1['baseRent'].min(),2), "Euro/month")
            print("The maximum base rent in postal code",str(plz),"is", round(plz_1['baseRent'].max(),2), "Euro/month")
            print("")
            display(plz_1.describe(include=[object]).T)
            input("Press [Enter] to go back to menu.\n")
        else:
            print("No record found.")
            input("Press [Enter] to go back to menu.\n")
    elif command_1 == 3:
        try:
            city = input("please type the name of a city or village: \n")
            city_1 = immo.loc[immo['regio2'].str.contains(city, case=False)]
            if isinstance(city, str):
                print("")
                print(len(city_1), "records found in ",city,":")
                print("The average base rent in",str(city),"is", round(city_1['baseRent'].mean(),2), "Euro/month")
                print("The minimum base rent in",str(city),"is", round(city_1['baseRent'].min(),2), "Euro/month")
                print("The maximum base rent in",str(city),"is", round(city_1['baseRent'].max(),2), "Euro/month")
                print("")
                display(city_1.describe(include=[object]).T)
                print("")
                print("availabil postal codes:")
                print(city_1["geo_plz"].unique())
                print("")
                plt.figure(figsize = (20,10))
                ax = sns.barplot(x = 'geo_plz', y = 'baseRent', data = city_1)
                ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
                title = print("Base Rent Vs postal code")
                plt.title(title, fontsize = 20)
                plt.xlabel('Region', fontsize = 16)
                plt.ylabel('base Rent', fontsize = 16)
                plt.show()
                input("Press [Enter] to go back to menu.\n")
            else:
                print("invalid input")
                input("Press [Enter] to go back to menu.\n")
        except ValueError:
            print("invalid input")
            input("Press [Enter] to go back to menu.\n")
    elif command_1 == 4:
        try:
            print("")
            print("Nordrhein_Westfalen")
            print("Sachsen")
            print("Bayern")
            print("Sachsen_Anhalt")
            print("Hessen")
            print("Niedersachsen")
            print("Baden_Württemberg")
            print("Berlin")
            print("Thüringen")
            print("Rheinland_Pfalz")
            print("Brandenburg")
            print("Schleswig_Holstein")
            print("Mecklenburg_Vorpommern")
            print("Hamburg")
            print("Bremen")
            print("Saarland")
            print("")
            state = input("please type the name of the federal state as shown above: \n")
            state_1 = immo.loc[immo['regio1'].str.contains(state, case=False)]
            if isinstance(state, str):
                print("")
                print(len(state_1), "records found in ",state,":")
                print("The average base rent in",str(state),"is", round(state_1['baseRent'].mean(),2), "Euro/month")
                print("The minimum base rent in",str(state),"is", round(state_1['baseRent'].min(),2), "Euro/month")
                print("The maximum base rent in",str(state),"is", round(state_1['baseRent'].max(),2), "Euro/month")
                print("")
                display(state_1.describe(include=[object]).T)
                print("")
                print("availabil postal codes:")
                print(state_1["geo_plz"].unique())
                print("")
                input("Press [Enter] to go back to menu.\n")
            else:
                print("invalid input")
                input("Press [Enter] to go back to menu.\n")
        except ValueError:
            print("invalid input")
            input("Press [Enter] to go back to menu.\n")
    elif command_1 == 5:
        try:
            city = input("please type the name of a city or village: \n")
            city_1 = immo.loc[immo['regio2'].str.contains(city, case=False)]
            if isinstance(city, str):
                plz = city_1["geo_plz"].unique().tolist()
                print("")
                print(len(city_1), "records found in",city,":")
                print(len(plz), "postal codes found in ",city)
                print("The average base rent in",str(city),"is", round(city_1['baseRent'].mean(),2), "Euro/month")
                print("The minimum base rent in",str(city),"is", round(city_1['baseRent'].min(),2), "Euro/month")
                print("The maximum base rent in",str(city),"is", round(city_1['baseRent'].max(),2), "Euro/month")
                print("")
                for x in plz:
                    y = str(x)
                    city_2 = city_1
                    city_2.geo_plz = city_2.geo_plz.astype(str)
                    city_3 = city_2.loc[city_2['geo_plz'].str.contains(y, case=False)]
                    print('Number of records in postal code',x,': ', len(city_3))
                    print("The average base rent in postal code",x,"is", round(city_3['baseRent'].mean(),2), "Euro/month")
                    print("The minimum base rent in postal code",x,"is", round(city_3['baseRent'].min(),2), "Euro/month")
                    print("The maximum base rent in postal code",x,"is", round(city_3['baseRent'].max(),2), "Euro/month")
                    print("")
                plt.figure(figsize = (20,10))
                ax = sns.barplot(x = 'geo_plz', y = 'baseRent', data = city_1)
                ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
                title = print("Base Rent Vs Postal Code in ", city,":")
                plt.title(title, fontsize = 20)
                plt.xlabel('Postal Code', fontsize = 16)
                plt.ylabel('base Rent', fontsize = 16)
                plt.show()
                input("Press [Enter] to go back to menu.\n")
            else:
                print("invalid input")
                input("Press [Enter] to go back to menu.\n")
        except ValueError:
            print("invalid input")
            input("Press [Enter] to go back to menu.\n")
    elif command_1 == 6:
        print("")
        print("You have finished the program")
        print("")
    else:
        print("invalid input")
        input("Press [Enter] to go back to menu.\n")
# Out:
# MAINMENU "INFO BASE RENT GERMANY".
# Press [1] Info base rent germany.
# Press [2] Postal code search.
# Press [3] City search.
# Press [4] Federal state search..
# Press [5] deep City search.
# Press [6] to exit the program.
#
# Please chose an option by pressing number [1] - [6] and confirm afterwards with [Enter].
# 1
#
#
# AVERAGE BASE RENT IN FEDERAL STATE OF GERMANY:
#
# 62679 records found in Nordrhein Westfalen:
# The average base rent in Nordrhein Westfalen is:  599.41 Euro/month
# The minimum base rent in Nordrhein Westfalen is:  106.08 Euro/month
# The maximum base rent in Nordrhein Westfalen is:  8160.0 Euro/month
#
# 57946 records found in Sachsen:
# The average base rent in Sachsen is:  437.9 Euro/month
# The minimum base rent in Sachsen is:  104.29 Euro/month
# The maximum base rent in Sachsen is:  7500.0 Euro/month
#
# 21457 records found in Bayern:
# The average base rent in Bayern is:  1014.54 Euro/month
# The minimum base rent in Bayern is:  115.0 Euro/month
# ...
