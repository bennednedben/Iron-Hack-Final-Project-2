# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ![Overview2%20%281%29%20(1).jpg](attachment:Overview2%20%281%29%20(1).jpg)

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
immo_with_NaN = pd.read_csv('immo_data.csv') #original Data
immo = pd.read_csv('immo.csv') # cleaned Data
alt_immo = pd.read_csv('alt_immo.csv') #original Data with column "Euro/m2"

# %%
display(immo.shape)
display(immo_with_NaN.shape)
# Out:
# (267810, 52)
# (268850, 49)

# %%
pd.set_option('display.max_columns', None)
immo.head(1)
# Out:
#    Unnamed: 0               regio1  serviceCharge      heatingType  \
# 0           0  Nordrhein_Westfalen          245.0  central_heating
#
#   telekomTvOffer  telekomHybridUploadSpeed  newlyConst  balcony  picturecount  \
# 0  ONE_YEAR_FREE                       0.0       False    False             6
#
#    pricetrend  telekomUploadSpeed  totalRent  yearConstructed   scoutId  \
# 0        4.62                10.0      840.0           1965.0  96107057
#
#    noParkSpaces firingTypes  hasKitchen              geo_bln  cellar  \
# 0           1.0         oil       False  Nordrhein_Westfalen    True
#
#    yearConstructedRange  baseRent houseNumber  livingSpace   geo_krs  \
# 0                   2.0     595.0         244         86.0  Dortmund
#
#    condition interiorQual petsAllowed                      street  \
# 0  well_kept       normal     unknown  Sch&uuml;ruferstra&szlig;e
#
#        streetPlain   lift  baseRentRange    typeOfFlat  geo_plz  noRooms  \
# ...

# %%
immo_with_NaN.head(1)
# Out:
#                 regio1  serviceCharge      heatingType telekomTvOffer  \
# 0  Nordrhein_Westfalen          245.0  central_heating  ONE_YEAR_FREE
#
#    telekomHybridUploadSpeed  newlyConst  balcony  picturecount  pricetrend  \
# 0                       NaN       False    False             6        4.62
#
#    telekomUploadSpeed  totalRent  yearConstructed   scoutId  noParkSpaces  \
# 0                10.0      840.0           1965.0  96107057           1.0
#
#   firingTypes  hasKitchen              geo_bln  cellar  yearConstructedRange  \
# 0         oil       False  Nordrhein_Westfalen    True                   2.0
#
#    baseRent houseNumber  livingSpace   geo_krs  condition interiorQual  \
# 0     595.0         244         86.0  Dortmund  well_kept       normal
#
#   petsAllowed                      street      streetPlain   lift  \
# 0         NaN  Sch&uuml;ruferstra&szlig;e  Schüruferstraße  False
#
#    baseRentRange    typeOfFlat  geo_plz  noRooms  thermalChar  floor  \
# ...

# %%
alt_immo.head(1)
# Out:
#    Unnamed: 0               regio1  serviceCharge      heatingType  \
# 0           0  Nordrhein_Westfalen          245.0  central_heating
#
#   telekomTvOffer  telekomHybridUploadSpeed  newlyConst  balcony  picturecount  \
# 0  ONE_YEAR_FREE                       NaN       False    False             6
#
#    pricetrend  telekomUploadSpeed  totalRent  yearConstructed   scoutId  \
# 0        4.62                10.0      840.0           1965.0  96107057
#
#    noParkSpaces firingTypes  hasKitchen              geo_bln  cellar  \
# 0           1.0         oil       False  Nordrhein_Westfalen    True
#
#    yearConstructedRange  baseRent houseNumber  livingSpace   geo_krs  \
# 0                   2.0     595.0         244         86.0  Dortmund
#
#    condition interiorQual petsAllowed                      street  \
# 0  well_kept       normal         NaN  Sch&uuml;ruferstra&szlig;e
#
#        streetPlain   lift  baseRentRange    typeOfFlat  geo_plz  noRooms  \
# ...

# %% [markdown]
# # Region

# %%
plt.figure(figsize=(20,10))
immo['regio1'].value_counts(normalize=True).plot(kind="bar")
plt.ylabel("relative frequency", fontsize=20)
plt.xlabel("Federal State", fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.show()

# %%
plt.figure(figsize = (20,10))
ax = sns.barplot(x = 'regio1', y = 'baseRent', data = immo)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
title = print("Base Rent Vs Region")
plt.title(title, fontsize = 30)
plt.xlabel('Region', fontsize = 20)
plt.ylabel('base Rent', fontsize = 20)
plt.show()
# Out:
# Base Rent Vs Region

# %%
pd.set_option('display.max_columns', None)
immo["geo_bln"].value_counts(dropna=False)
# Out:
# Nordrhein_Westfalen       62679
# Sachsen                   57946
# Bayern                    21457
# Sachsen_Anhalt            20085
# Hessen                    17739
# Niedersachsen             16527
# Baden_Württemberg         15994
# Berlin                    10327
# Thüringen                  8370
# Rheinland_Pfalz            8356
# Brandenburg                6933
# Schleswig_Holstein         6651
# Mecklenburg_Vorpommern     6621
# Hamburg                    3747
# Bremen                     2960
# Saarland                   1418
# Name: geo_bln, dtype: int64

# %% [markdown]
# # serviceCharge

# %%
immo_serviceCharge=immo_with_NaN[immo_with_NaN.serviceCharge <= 600]
sns.displot(immo_serviceCharge["serviceCharge"], kde=True, height=8, aspect=12/8)
plt.show()

# %% [markdown]
# # Heating Type

# %%
plt.figure(figsize=(20,10))
sns.countplot('heatingType', data=immo)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('Heating Type', fontsize=20)
plt.xticks(rotation=90, fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# # firing Types

# %%
plt.figure(figsize=(20,10))
sns.countplot('firingTypes', data=immo)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('firing Types', fontsize=20)
plt.xticks(rotation=90, fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# # newly Const

# %%
plt.figure(figsize=(6,6))
sns.countplot('newlyConst', data=immo)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('newly Constructed', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# # Balcony

# %%
plt.figure(figsize=(6,6))
sns.countplot('balcony', data=immo)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('balcony', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
newlyConst = immo_with_NaN[immo_with_NaN.newlyConst == True]
not_newlyConst = immo_with_NaN[immo_with_NaN.newlyConst == False]

# %%
plt.figure(figsize=(6,6))
sns.countplot('balcony', data=newlyConst)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('Balcony on Building newly constructed', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot('balcony', data=not_newlyConst)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('Balcony on old Building', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# # picture count

# %%
picture = immo_with_NaN[immo_with_NaN.picturecount <= 30]

# %%
plt.figure(figsize=(10,6))
sns.countplot('picturecount', data=picture)
plt.ylabel('Value Count', fontsize=15)
plt.xlabel('picture count', fontsize=15)
plt.xticks(rotation=90, fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
immo_with_NaN["baseRent"].mean()
# Out:
# 694.1294320252957

# %%
picture_high_rent = picture[picture.baseRent >= 700]
picture_low_rent = picture[picture.baseRent < 700]

# %%
plt.figure(figsize=(10,6))
sns.countplot('picturecount', data=picture_high_rent)
plt.ylabel('Value Count', fontsize=15)
plt.xlabel('picture count for high rents', fontsize=15)
plt.xticks(rotation=90, fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot('picturecount', data=picture_low_rent)
plt.ylabel('Value Count', fontsize=15)
plt.xlabel('picture count for low rents', fontsize=15)
plt.xticks(rotation=90, fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# # price trend

# %%
round(immo_with_NaN["pricetrend"].describe(),0).T
# Out:
# count    267018.0
# mean          3.0
# std           2.0
# min         -12.0
# 25%           2.0
# 50%           3.0
# 75%           5.0
# max          15.0
# Name: pricetrend, dtype: float64

# %%
immo_with_NaN = pd.read_csv('immo_data.csv')
immo_with_NaN[["pricetrend"]].boxplot()
plt.show()

# %%
sns.displot(immo_with_NaN["pricetrend"], kde=True, height=8, aspect=12/8)
plt.show()

# %% [markdown]
# # base Rent and total Rent

# %%
print(immo.baseRent.mean())
print(immo.totalRent.mean())
# Out:
# 646.3701654531222
# 813.4290675486807

# %%
minimum = np.percentile(immo.baseRent,0)
maximum = np.percentile(immo.baseRent,100)
bins = [x for x in range(int(maximum)) if x%100==0]
baseRent=immo.baseRent.loc[immo.baseRent.between(minimum,maximum)]
totalRent=immo.totalRent.loc[immo.totalRent.between(minimum,maximum)]
plt.figure(figsize=(20,10))
plt.hist(baseRent,bins=bins,alpha=0.6,color="Red",label="Base Rent")
plt.plot([baseRent.mean(),baseRent.mean()],[0,50000],color="black")
plt.hist(totalRent,bins=bins,alpha=0.6,color="Blue",label="Total Rent")
plt.plot([totalRent.mean(), totalRent.mean()],[0,50000],color="black")
plt.annotate("Ø Base Rent: "+str(int(baseRent.mean()))+" Euro/month", xy=(647, 39700), xytext=(1200, 40000),
            arrowprops=dict(facecolor='black'))
plt.annotate("Ø Total Rent: "+str(int(totalRent.mean()))+" Euro/month", xy=(814, 29700), xytext=(1400, 30000),
            arrowprops=dict(facecolor='black'))
plt.xticks(bins,rotation=90, fontsize=10)
plt.xlabel("Rent", fontsize=20)
plt.ylabel("Frequency", fontsize=20)
plt.legend()
plt.show()

# %%
baseRent=immo_with_NaN.baseRent
totalRent=immo_with_NaN.totalRent.dropna()
base_color="Red"
total_color="Blue"
percentiles = (25,75)
base_percentile_values=[np.percentile(baseRent,x).astype(int) for x in percentiles]
total_percentile_values=[np.percentile(totalRent,x).astype(int) for x in percentiles]
x_values = [np.percentile(baseRent,x+1) for x in range(1,99)]
plt.figure(figsize=(20,10))
plt.step(x_values,[x/100 for x in range(1,99)],label="Base Rent",color=base_color)
for percentile in percentiles:
    plt.plot([np.percentile(baseRent,percentile),np.percentile(baseRent,percentile)],
            [0,1],color=base_color,linestyle="--",alpha=0.6)
x_values = [np.percentile(totalRent,x+1) for x in range(1,99)]
plt.step(x_values,[x/100 for x in range(1,99)],label="Total Rent",color=total_color)
for percentile in percentiles:
    plt.plot([np.percentile(totalRent,percentile),np.percentile(totalRent,percentile)],
            [0,1],color=total_color,linestyle="--",alpha=0.6)
xtick_list=sorted(np.array([base_percentile_values,total_percentile_values]).flatten().astype(int))
plt.xticks([x for x in range(0,int(max(x_values))) if x%100==0],rotation=90, fontsize=15)
plt.yticks([x/100 for x in range(101) if x%10==0], fontsize=15)
plt.ylim(0,1)
plt.legend()
plt.grid(alpha=0.3)
plt.fill_between(base_percentile_values,percentiles,color=base_color,alpha=0.2)
plt.fill_between(total_percentile_values,percentiles,color=total_color,alpha=0.2)
plt.xlabel("Rent", fontsize=20)
plt.ylabel("Cumulative Frequency", fontsize=20)
plt.show()
# red block: area between 25% and 75% quantiles for Base Rent
# blue block: area between 25% and 75% quantiles for Total Rent

# %%
sns.displot(immo["baseRent"], kde=True, height=8, aspect=12/8)
plt.show()

# %%
plt.figure(figsize = (20,10))
ax = sns.barplot(x = 'regio1', y = 'baseRent', data = immo)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
plt.title('Base Rent Vs Federal State', fontsize = 20)
plt.xlabel('Federal State', fontsize = 16)
plt.ylabel('baseRent', fontsize = 16)
# Out:
# Text(0, 0.5, 'baseRent')

# %% [markdown]
# # Living Space

# %%
livingSpace=immo_with_NaN.livingSpace.dropna()
color="Red"
percentiles = (25,75)
livingSpace_percentile_values=[np.percentile(livingSpace,x).astype(int) for x in percentiles]
x_values = [np.percentile(livingSpace,x+1) for x in range(1,99)]
plt.figure(figsize=(20,10))
plt.step(x_values,[x/100 for x in range(1,99)],label="Living Space",color=color)
for percentile in percentiles:
    plt.plot([np.percentile(livingSpace,percentile),np.percentile(livingSpace,percentile)],
            [0,1],color=color,linestyle="--",alpha=0.5)
x_values = [np.percentile(livingSpace,x+1) for x in range(1,99)]
xtick_list=sorted(np.array([livingSpace_percentile_values]).flatten().astype(int))
plt.xticks([x for x in range(0,int(max(x_values))) if x%10==0],rotation=90, fontsize=15)
plt.yticks([x/100 for x in range(101) if x%10==0], fontsize=15)
plt.ylim(0,1)
plt.legend()
plt.grid(alpha=0.3)
plt.fill_between(livingSpace_percentile_values,percentiles,color=color,alpha=0.2)
plt.xlabel("Living Space [m²]", fontsize=20)
plt.ylabel("Cumulative Frequency", fontsize=20)
plt.show()

# %%
# livingSpaceRange

# %%
plt.figure(figsize=(10,6))
sns.countplot('livingSpaceRange', data=immo_with_NaN)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('living Space Range', fontsize=20)
plt.xticks(rotation=90, fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# # year Constructed

# %%
year = immo_with_NaN[immo_with_NaN.yearConstructed >= 1850]
yearConstructed=year.yearConstructed.dropna()
color="Blue"
percentiles = (25,75)
yearConstructed_percentile_values=[np.percentile(yearConstructed,x).astype(int) for x in percentiles]
x_values = [np.percentile(yearConstructed,x+1) for x in range(1,99)]
plt.figure(figsize=(20,10))
plt.step(x_values,[x/100 for x in range(1,99)],label="Year Constructed",color=color)
for percentile in percentiles:
    plt.plot([np.percentile(yearConstructed,percentile),np.percentile(yearConstructed,percentile)],
            [0,1],color=color,linestyle="--",alpha=0.5)
x_values = [np.percentile(yearConstructed,x+1) for x in range(1,99)]
xtick_list=sorted(np.array([yearConstructed_percentile_values]).flatten().astype(int))
plt.xticks([x for x in range(0,int(max(x_values))) if x%10==0],rotation=90, fontsize=15)
plt.yticks([x/100 for x in range(101) if x%10==0], fontsize=15)
plt.ylim(0,1)
plt.legend()
plt.grid(alpha=0.3)
plt.fill_between(yearConstructed_percentile_values,percentiles,color=color,alpha=0.2)
plt.xlabel("Year Constructed", fontsize=20)
plt.ylabel("Cumulative Frequency", fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,10))
immo_with_NaN.yearConstructed.hist(bins=[x for x in range(1850,2021) if x%1==0])
plt.xticks([x for x in range(1850,2021) if x%5==0],rotation=90, fontsize=15)
plt.yticks(fontsize=15)
plt.grid(alpha=0.2)
plt.xlabel("Year", fontsize=20)
plt.ylabel("units every 5 years since 1850", fontsize=20)
plt.show()

# %%
immo_with_NaN.yearConstructed.isna().sum()
# Out:
# 57045

# %% [markdown]
# # cellar

# %%
plt.figure(figsize=(6,6))
sns.countplot('cellar', data=immo)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('cellar', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot('cellar', data=newlyConst)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('Cellar on Building newly constructed', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot('cellar', data=not_newlyConst)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('Cellar on old Building', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
print(immo_with_NaN.cellar.value_counts())
all_count = len(immo_with_NaN)
cellar = 172235*100/all_count
print("")
print(round(cellar, 2), "percent of the buildings in the dataset have a cellar")
# Out:
# True     172235
# False     96615
# Name: cellar, dtype: int64
#
# 64.06 percent of the buildings in the dataset have a cellar

# %%
print(newlyConst.cellar.value_counts())
all_count2 = len(newlyConst)
cellar2 = 13420*100/all_count2
print("")
print(round(cellar2, 2), "percent of the new buildings in the dataset have a cellar")
# Out:
# True     13420
# False     7751
# Name: cellar, dtype: int64
#
# 63.39 percent of the new buildings in the dataset have a cellar

# %%
print(not_newlyConst.cellar.value_counts())
all_count3 = len(not_newlyConst)
cellar3 = 158815*100/all_count3
print("")
print(round(cellar3, 2), "percent of the old buildings in the dataset have a cellar")
# Out:
# True     158815
# False     88864
# Name: cellar, dtype: int64
#
# 64.12 percent of the old buildings in the dataset have a cellar

# %% [markdown]
# # condition

# %%
plt.figure(figsize=(10,6))
sns.countplot('condition', data=immo_with_NaN)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('condition', fontsize=20)
plt.xticks(fontsize=15, rotation=90)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# # interior Quality

# %%
plt.figure(figsize=(6,6))
sns.countplot('interiorQual', data=immo_with_NaN)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('interior Quality', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# # Pets allowed

# %%
plt.figure(figsize=(6,6))
sns.countplot('petsAllowed', data=immo_with_NaN)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('Pets allowed', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
# negotiable = verhandelbar

# %%
# Lift

# %%
plt.figure(figsize=(6,6))
sns.countplot('lift', data=immo_with_NaN)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('Lift', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot('lift', data=newlyConst)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('Lift on Building newly constructed', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot('lift', data=not_newlyConst)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('Lift in old Building', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# # Type of Flat

# %%
plt.figure(figsize=(10,6))
sns.countplot('typeOfFlat', data=immo_with_NaN)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('Type of Flat', fontsize=20)
plt.xticks(rotation=90, fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# # Number of Rooms

# %%
immo_rooms=immo_with_NaN[immo_with_NaN.noRooms <= 10]
plt.figure(figsize=(10,6))
sns.countplot('noRooms', data=immo_rooms)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('Number of Rooms', fontsize=20)
plt.xticks(rotation=90, fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# # Number of Rooms range

# %%
plt.figure(figsize=(10,6))
sns.countplot('noRoomsRange', data=immo_with_NaN)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('Number of Rooms', fontsize=20)
plt.xticks(rotation=90, fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# # Floor

# %%
immo_floor=immo_with_NaN[immo_with_NaN.floor <= 20]
plt.figure(figsize=(10,6))
sns.countplot('floor', data=immo_floor)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('Floor', fontsize=20)
plt.xticks(rotation=90, fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# # Number of Floors

# %%
immo_numberOfFloors=immo_with_NaN[immo_with_NaN.numberOfFloors <= 20]
plt.figure(figsize=(10,6))
sns.countplot('numberOfFloors', data=immo_numberOfFloors)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('Number of Floors', fontsize=20)
plt.xticks(rotation=90, fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# # Garden

# %%
plt.figure(figsize=(10,6))
sns.countplot('garden', data=immo_with_NaN)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('Garden', fontsize=20)
plt.xticks(rotation=90, fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# # Heating Costs

# %%
immo_heatingCosts=immo_with_NaN[immo_with_NaN.heatingCosts <= 300]
sns.displot(immo_heatingCosts["heatingCosts"], kde=True, height=8, aspect=12/8)
plt.show()

# %% [markdown]
# # energy Efficiency Class

# %%
plt.figure(figsize=(10,6))
sns.countplot('energyEfficiencyClass', data=immo_with_NaN, order=['A_PLUS','A','B','C','D','E','F','G','H'])
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('Energy Efficiency Class', fontsize=20)
plt.xticks(rotation=90, fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# df = immo_with_NaN

# df['energyEfficiencyClass'].value_counts().plot(kind="bar")

# plt.show()

# %% [markdown]
# # last Refurbish

# %%
immo_lastRefurbish=immo_with_NaN[immo_with_NaN.lastRefurbish >= 1980]
immo_lastRefurbish=immo_lastRefurbish[immo_lastRefurbish.lastRefurbish <= 2020]
plt.figure(figsize=(20,10))
sns.countplot('lastRefurbish', data=immo_lastRefurbish)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('last Refurbish', fontsize=20)
plt.xticks(rotation=90, fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# # Euro/m2

# %%
sns.displot(immo['Euro/m2'], kde=True, height=8, aspect=12/8)
plt.show()
display(round(immo['Euro/m2'].mean(), 2))
# Out:
# 8.7

# %%
plt.figure(figsize = (10,5))
ax = sns.barplot(x = 'regio1', y = 'Euro/m2', data = immo)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
title = print("Base Rent Vs Region")
plt.title(title, fontsize = 30)
plt.xlabel('Region', fontsize = 10)
plt.ylabel('Euro/m2', fontsize = 10)
plt.show()
# Out:
# Base Rent Vs Region

# %%
# price=alt_immo['Euro/m2'].dropna()
# color="Red"
# percentiles = (25,75)
# price_percentile_values=[np.percentile(price,x).astype(int) for x in price]
# x_values = [np.percentile(price,x+1) for x in range(1,99)]
# plt.figure(figsize=(20,10))
# plt.step(x_values,[x/100 for x in range(1,99)],label="Euro/m2",color=color)
# for percentile in percentiles:
#     plt.plot([np.percentile(price,percentile),np.percentile(price,percentile)],
#             [0,1],color=color,linestyle="--",alpha=0.5)
# x_values = [np.percentile(price,x+1) for x in range(1,99)]
# xtick_list=sorted(np.array([price_percentile_values]).flatten().astype(int))
# plt.xticks([x for x in range(0,int(max(x_values))) if x%10==0],rotation=90, fontsize=15)
# plt.yticks([x/100 for x in range(101) if x%10==0], fontsize=15)
# plt.ylim(0,1)
# plt.legend()
# plt.grid(alpha=0.3)
# plt.fill_between(price_percentile_values,percentiles,color=color,alpha=0.2)
# plt.xlabel("price in Euro/m²", fontsize=20)
# plt.ylabel("Cumulative Frequency", fontsize=20)
# plt.show()

# %% [markdown]
# # price class

# %%
'''
price class 1  = 0-4   Euro/m²
price class 2  = 4-5   Euro/m²
price class 3  = 5-6   Euro/m²
price class 4  = 6-7   Euro/m²
price class 5  = 7-8   Euro/m²
price class 6  = 8-9   Euro/m²
price class 7  = 9-10  Euro/m²
price class 8  = 10-12 Euro/m²
price class 9  = 12-14 Euro/m²
price class 10 = 14-16 Euro/m²
price class 11 = 16-20 Euro/m²
price class 12 = 20-25 Euro/m²
price class 13 = 25-30 Euro/m²
price class 14 = 30-40 Euro/m²
price class 15 = 40-50 Euro/m²
'''
plt.figure(figsize=(10,6))
sns.countplot('price_class', data=immo)
plt.ylabel('Value Count', fontsize=20)
plt.xlabel('price class', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
sns.scatterplot(x='price_class',y='regio1',data=immo, alpha=0.005, s=800)
#sns.set(font_scale=4)
plt.show()

# %%
data_yearConstructed = alt_immo[alt_immo.yearConstructed >= 1880]
data_yearConstructed = data_yearConstructed[data_yearConstructed.yearConstructed <= 2021]
fig = plt.figure(figsize=(10,15))
sns.scatterplot(x='price_class',y='yearConstructed',data=data_yearConstructed, alpha=0.002, s=40)
plt.show()

# %%
fig = plt.figure(figsize=(10,15))
sns.scatterplot(x='price_class',y='heatingType',data=alt_immo, alpha=0.002, s=300)
plt.show()

# %%
fig = plt.figure(figsize=(10,15))
sns.scatterplot(x='price_class',y='firingTypes',data=immo, alpha=0.002, s=300)
plt.show()

# %%
data_livingSpace = immo[immo.livingSpace <= 300]
fig = plt.figure(figsize=(10,15))
sns.scatterplot(x='price_class',y='livingSpace',data=data_livingSpace, alpha=0.002, s=300)
plt.show()

# %%
fig = plt.figure(figsize=(10,15))
sns.scatterplot(x='price_class',y='condition',data=alt_immo, alpha=0.002, s=300)
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
sns.scatterplot(x='price_class',y='interiorQual',data=alt_immo, alpha=0.002, s=300)
plt.show()

# %%
fig = plt.figure(figsize=(10,15))
sns.scatterplot(x='price_class',y='baseRentRange',data=alt_immo, alpha=0.002, s=300)
plt.show()

# %%
fig = plt.figure(figsize=(10,15))
sns.scatterplot(x='price_class',y='typeOfFlat',data=alt_immo, alpha=0.002, s=300)
plt.show()

# %%
data_noRooms = alt_immo[alt_immo.noRooms <= 10]
fig = plt.figure(figsize=(10,15))
sns.scatterplot(x='price_class',y='noRooms',data=data_noRooms, alpha=0.002, s=300)
plt.show()

# %%
data_floor = alt_immo[alt_immo.floor <= 10]
fig = plt.figure(figsize=(10,15))
sns.scatterplot(x='price_class',y='floor',data=data_floor, alpha=0.002, s=300)
plt.show()

# %%
fig = plt.figure(figsize=(10,15))
sns.scatterplot(x='price_class',y='numberOfFloors',data=immo, alpha=0.002, s=300)
plt.show()

# %%
fig = plt.figure(figsize=(10,15))
sns.scatterplot(x='price_class',y='energyEfficiencyClass',data=alt_immo, alpha=0.002, s=300)
plt.show()

# %%
data_lastRefurbish = alt_immo[alt_immo.lastRefurbish <= 2021]
data_lastRefurbish = data_lastRefurbish[data_lastRefurbish.lastRefurbish >= 1990]
fig = plt.figure(figsize=(10,15))
sns.scatterplot(x='price_class',y='lastRefurbish',data=data_lastRefurbish, alpha=0.002, s=300)
plt.show()

# %%
alt_immo.sort_values('energyEfficiencyClass', ascending=True, inplace=True)
data_lastRefurbish = alt_immo[alt_immo.lastRefurbish <= 2021]
data_lastRefurbish = data_lastRefurbish[data_lastRefurbish.lastRefurbish >= 1900]
fig = plt.figure(figsize=(7,10))
sns.scatterplot(x='energyEfficiencyClass',y='lastRefurbish',data=data_lastRefurbish, alpha=0.002, s=300)
plt.show()

# %%
alt_immo.sort_values('energyEfficiencyClass', ascending=True, inplace=True)
alt_immo_1 = alt_immo[alt_immo.yearConstructed >= 1900]
fig = plt.figure(figsize=(7,10))
sns.scatterplot(x='energyEfficiencyClass',y='yearConstructed',data=alt_immo_1, alpha=0.002, s=300)
plt.show()

# %%
display(immo.shape)
# Out:
# (267810, 52)
